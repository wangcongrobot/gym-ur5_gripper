# %%
from ray import tune
from ray.rllib.agents.ppo import PPOTrainer
tune.run(PPOTrainer, config={"env": "CartPole-v0"})  # "eager": True for eager execution
# Out:
# /home/cong/workspace/DHER/dher-env/lib/python3.5/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.25.1) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-e925fc17e7fc> in <module>
#       1 from ray import tune
# ----> 2 from ray.rllib.agents.ppo import PPOTrainer
#       3 tune.run(PPOTrainer, config={"env": "CartPole-v0"})  # "eager": True for eager execution
#
# ~/workspace/DHER/ray/python/ray/rllib/__init__.py in <module>
#      68
#      69 _setup_logger()
# ---> 70 _register_all()
#      71
#      72 __all__ = [
#
# ~/workspace/DHER/ray/python/ray/rllib/__init__.py in _register_all()
#      45     for key in list(ALGORITHMS.keys()) + list(CONTRIBUTED_ALGORITHMS.keys(
#      46     )) + ["__fake", "__sigmoid_fake_data", "__parameter_tuning"]:
# ---> 47         register_trainable(key, get_agent_class(key))
#      48
#      49     def _see_contrib(name):
#
# ~/workspace/DHER/ray/python/ray/rllib/agents/registry.py in get_agent_class(alg)
#     126
#     127     try:
# --> 128         return _get_agent_class(alg)
#     129     except ImportError:
#     130         from ray.rllib.agents.mock import _agent_import_failed
#
# ~/workspace/DHER/ray/python/ray/rllib/agents/registry.py in _get_agent_class(alg)
#     134 def _get_agent_class(alg):
#     135     if alg in ALGORITHMS:
# --> 136         return ALGORITHMS[alg]()
#     137     elif alg in CONTRIBUTED_ALGORITHMS:
#     138         return CONTRIBUTED_ALGORITHMS[alg]()
#
# ~/workspace/DHER/ray/python/ray/rllib/agents/registry.py in _import_sac()
#      11
#      12 def _import_sac():
# ---> 13     from ray.rllib.agents import sac
#      14     return sac.SACTrainer
#      15
#
# ~/workspace/DHER/ray/python/ray/rllib/agents/sac/__init__.py in <module>
#       3 from __future__ import print_function
#       4
# ----> 5 from ray.rllib.agents.sac.sac import SACTrainer, DEFAULT_CONFIG
#       6 from ray.rllib.utils import renamed_agent
#       7
#
# ~/workspace/DHER/ray/python/ray/rllib/agents/sac/sac.py in <module>
#       5 from ray.rllib.agents.trainer import with_common_config
#       6 from ray.rllib.agents.dqn.dqn import GenericOffPolicyTrainer
# ----> 7 from ray.rllib.agents.sac.sac_policy import SACTFPolicy
#       8
#       9 OPTIMIZER_SHARED_CONFIGS = [
#
# ~/workspace/DHER/ray/python/ray/rllib/agents/sac/sac_policy.py in <module>
#       9 import ray
#      10 import ray.experimental.tf_utils
# ---> 11 from ray.rllib.agents.sac.sac_model import SACModel
#      12 from ray.rllib.agents.ddpg.noop_model import NoopModel
#      13 from ray.rllib.agents.ddpg.ddpg_policy import ComputeTDErrorMixin, \
#
# ~/workspace/DHER/ray/python/ray/rllib/agents/sac/sac_model.py in <module>
#       9
#      10 tf = try_import_tf()
# ---> 11 tfp = try_import_tfp()
#      12
#      13 SCALE_DIAG_MIN_MAX = (-20, 2)
#
# ~/workspace/DHER/ray/python/ray/rllib/utils/__init__.py in try_import_tfp()
#      87
#      88     try:
# ---> 89         import tensorflow_probability as tfp
#      90         return tfp
#      91     except ImportError:
#
# ~/workspace/DHER/dher-env/lib/python3.5/site-packages/tensorflow_probability/__init__.py in <module>
#      73
#      74 # from tensorflow_probability.google import staging  # DisableOnExport
# ---> 75 from tensorflow_probability.python import *  # pylint: disable=wildcard-import
#      76 from tensorflow_probability.python.version import __version__
#      77 # pylint: enable=g-import-not-at-top
#
# ~/workspace/DHER/dher-env/lib/python3.5/site-packages/tensorflow_probability/python/__init__.py in <module>
#      19 from __future__ import print_function
#      20
# ---> 21 from tensorflow_probability.python import bijectors
#      22 from tensorflow_probability.python import debugging
#      23 from tensorflow_probability.python import distributions
#
# ~/workspace/DHER/dher-env/lib/python3.5/site-packages/tensorflow_probability/python/bijectors/__init__.py in <module>
#      31 from tensorflow_probability.python.bijectors.cholesky_outer_product import CholeskyOuterProduct
#      32 from tensorflow_probability.python.bijectors.cholesky_to_inv_cholesky import CholeskyToInvCholesky
# ---> 33 from tensorflow_probability.python.bijectors.correlation_cholesky import CorrelationCholesky
#      34 from tensorflow_probability.python.bijectors.cumsum import Cumsum
#      35 from tensorflow_probability.python.bijectors.discrete_cosine_transform import DiscreteCosineTransform
#
# ~/workspace/DHER/dher-env/lib/python3.5/site-packages/tensorflow_probability/python/bijectors/correlation_cholesky.py in <module>
#      24
#      25 from tensorflow_probability.python.bijectors import bijector
# ---> 26 from tensorflow_probability.python.bijectors import fill_triangular
#      27 from tensorflow_probability.python.internal import prefer_static
#      28
#
# ~/workspace/DHER/dher-env/lib/python3.5/site-packages/tensorflow_probability/python/bijectors/fill_triangular.py in <module>
#      24 import tensorflow.compat.v2 as tf
#      25
# ---> 26 from tensorflow_probability.python import math as tfp_math
#      27 from tensorflow_probability.python.bijectors import bijector
#      28 from tensorflow_probability.python.internal import assert_util
#
# ~/workspace/DHER/dher-env/lib/python3.5/site-packages/tensorflow_probability/python/math/__init__.py in <module>
#      33 from tensorflow_probability.python.math.interpolation import batch_interp_regular_nd_grid
#      34 from tensorflow_probability.python.math.interpolation import interp_regular_1d_grid
# ---> 35 from tensorflow_probability.python.math.linalg import cholesky_concat
#      36 from tensorflow_probability.python.math.linalg import fill_triangular
#      37 from tensorflow_probability.python.math.linalg import fill_triangular_inverse
#
# ~/workspace/DHER/dher-env/lib/python3.5/site-packages/tensorflow_probability/python/math/linalg.py in <module>
#      55     'tfp.math.matrix_rank is deprecated. Use tf.linalg.matrix_rank instead',
#      56     warn_once=True)(
# ---> 57         tf.linalg.matrix_rank)
#      58
#      59
#
# AttributeError: module 'tensorflow._api.v1.compat.v2.linalg' has no attribute 'matrix_rank'
